# %%
from ultralytics import YOLO
import cv2
import pyttsx3  
import time
import psutil

# Text-to-speech
engine = pyttsx3.init()
engine.setProperty('rate', 200)  # Speed of speech
engine.setProperty('volume', 1.0)  

# Load YOLO model
model = YOLO('yolov8n.pt')

def log_metrics(detections, start_time):
    #latency
    end_time = time.time()
    latency = end_time - start_time  
    #memory usage (in MB)
    process = psutil.Process()
    memory_info = process.memory_info()
    memory_usage = memory_info.rss / (1024 * 1024)  #byte to mb
    # Log metrics
    print(f"Latency: {latency:.4f} seconds")
    print(f"Memory Usage: {memory_usage:.2f} MB")


def calculate_distance(bbox_height, frame_height, actual_height=1.7):
    focal_length = 700  
    if bbox_height > 0:
        distance = (actual_height * focal_length) / (bbox_height / frame_height)
        return distance  
    return float('inf') 

def filter_detections(detections):
    filtered = []
    for detection in detections:
        class_id = int(detection[5])  
        class_name = model.names[class_id]  
        filtered.append(detection)  
    return filtered


last_feedback_time = 0  # Store the last feedback time

def give_audio_feedback(detections, frame_height):
    global last_feedback_time
    current_time = time.time()

    #feedback every 0.5 seconds
    if current_time - last_feedback_time < 0.5:
        return

    if not detections:
        return

    for detection in detections:
        confidence = detection[4] * 100  #accuracy
        class_id = int(detection[5]) 
        class_name = model.names[class_id]  
        bbox_height = detection[3] - detection[1] 

        #distance
        distance = calculate_distance(bbox_height, frame_height)

        feedback_fast = ""
        feedback = ""
        
        # Warnings for different objects
        if confidence > 80 and distance < 4000:  
            if class_name == "person":
                if distance > 1700 and distance <= 4000:
                    feedback = f"Caution! Person ahead"
                    #print(feedback)
                    engine.say(feedback)
                    engine.runAndWait()
                elif distance <= 1700:
                    feedback_fast = f"Alert! Person very close"
                    print(feedback_fast)
                    engine.say(feedback_fast)
                    engine.runAndWait()
            else:
                if distance > 1700 and distance <= 4000:
                    feedback = f"Warning! {class_name} ahead"
                    print(feedback)
                    engine.say(feedback)
                    engine.runAndWait()
                elif distance <= 1700:
                    feedback_fast = f" danger! {class_name} {class_name}{class_name}{class_name}{class_name}"
                    print(feedback_fast)
                    engine.say(feedback_fast)
                    engine.runAndWait()
    print(f"Bounding box height: {bbox_height}")
    print(f"Frame height: {frame_height}")
    print("Distance is ", distance)
    
    last_feedback_time = current_time
    


# Real-Time Detection
def detect_from_camera():
    cap = cv2.VideoCapture(0)  #0 is system camera

    if not cap.isOpened():
        print("Error: Unable to access the camera.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Unable to read the camera feed.")
            break

        
        frame_height = frame.shape[0]

        # Run YOLOv8 inference
        results = model.predict(frame)
        # Filter detections
        filtered_detections = filter_detections(results[0].boxes.data.tolist())
        # Provide audio feedback for hazards
        give_audio_feedback(filtered_detections, frame_height)
        start_time = time.time()
        log_metrics(filtered_detections, start_time)

        # Annotate frame with detections
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Real-Time Detection", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# Run the detection
detect_from_camera()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 10.8MB/s]
# 0: 480x640 1 person, 459.3ms
# Speed: 12.0ms preprocess, 459.3ms inference, 17.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 382.24061584472656
# Frame height: 480
# Distance is  1494.3466924300697
# Latency: 0.0000 seconds
# Memory Usage: 602.38 MB
#
# 0: 480x640 1 person, 306.4ms
# Speed: 23.5ms preprocess, 306.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.26348876953125
# Frame height: 480
# Distance is  1518.0851106971775
# Latency: 0.0000 seconds
# Memory Usage: 614.55 MB
#
# 0: 480x640 1 person, 169.1ms
# Speed: 5.1ms preprocess, 169.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.57603454589844
# Frame height: 480
# Distance is  1516.8251497703316
# Latency: 0.0000 seconds
# Memory Usage: 616.42 MB
#
# 0: 480x640 1 person, 134.4ms
# Speed: 2.3ms preprocess, 134.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 375.60166931152344
# Frame height: 480
# Distance is  1520.760014317848
# Latency: 0.0000 seconds
# Memory Usage: 616.37 MB
#
# 0: 480x640 1 person, 157.4ms
# Speed: 8.1ms preprocess, 157.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 370.646484375
# Frame height: 480
# Distance is  1541.09110454179
# Latency: 0.0000 seconds
# Memory Usage: 617.59 MB
#
# 0: 480x640 1 person, 181.6ms
# Speed: 3.0ms preprocess, 181.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 378.07470703125
# Frame height: 480
# Distance is  1510.8125176773253
# Latency: 0.0000 seconds
# Memory Usage: 617.56 MB
#
# 0: 480x640 1 person, 275.8ms
# Speed: 4.0ms preprocess, 275.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 368.37835693359375
# Frame height: 480
# Distance is  1550.579694080584
# Latency: 0.0000 seconds
# Memory Usage: 617.51 MB
#
# 0: 480x640 1 person, 209.9ms
# Speed: 4.0ms preprocess, 209.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 365.5076904296875
# Frame height: 480
# Distance is  1562.7578159258496
# Latency: 0.0000 seconds
# Memory Usage: 617.49 MB
#
# 0: 480x640 1 person, 149.6ms
# Speed: 5.1ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.37303161621094
# Frame height: 480
# Distance is  1517.643274139936
# Latency: 0.0000 seconds
# Memory Usage: 618.68 MB
#
# 0: 480x640 1 person, 160.1ms
# Speed: 6.0ms preprocess, 160.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.434814453125
# Frame height: 480
# Distance is  1517.3941890306426
# Latency: 0.0000 seconds
# Memory Usage: 619.12 MB
#
# 0: 480x640 1 person, 330.6ms
# Speed: 8.2ms preprocess, 330.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.92767333984375
# Frame height: 480
# Distance is  1515.410091646408
# Latency: 0.0000 seconds
# Memory Usage: 620.32 MB
#
# 0: 480x640 1 cat, 271.3ms
# Speed: 7.1ms preprocess, 271.3ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 438.7738037109375
# Frame height: 480
# Distance is  1301.8097141831747
# Latency: 0.0000 seconds
# Memory Usage: 620.36 MB
#
# 0: 480x640 1 cat, 259.3ms
# Speed: 10.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 241.4ms
# Speed: 8.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 419.92979431152344
# Frame height: 480
# Distance is  1360.2273707120132
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 224.2ms
# Speed: 5.0ms preprocess, 224.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 237.8ms
# Speed: 8.0ms preprocess, 237.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 424.98541259765625
# Frame height: 480
# Distance is  1344.0461320981117
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 265.1ms
# Speed: 9.0ms preprocess, 265.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 218.9ms
# Speed: 8.0ms preprocess, 218.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 421.76361083984375
# Frame height: 480
# Distance is  1354.3131396817014
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 195.4ms
# Speed: 5.0ms preprocess, 195.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 194.9ms
# Speed: 7.0ms preprocess, 194.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 221.5ms
# Speed: 7.0ms preprocess, 221.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 422.80189514160156
# Frame height: 480
# Distance is  1350.9873218725713
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 1 vase, 188.0ms
# Speed: 8.0ms preprocess, 188.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.66 MB
#
# 0: 480x640 1 cat, 1 vase, 209.0ms
# Speed: 7.5ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 210.2ms
# Speed: 9.0ms preprocess, 210.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 422.966064453125
# Frame height: 480
# Distance is  1350.4629520066449
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 200.7ms
# Speed: 8.0ms preprocess, 200.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 194.1ms
# Speed: 11.0ms preprocess, 194.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 206.2ms
# Speed: 5.0ms preprocess, 206.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 419.79803466796875
# Frame height: 480
# Distance is  1360.6542976118974
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 228.8ms
# Speed: 5.0ms preprocess, 228.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 291.8ms
# Speed: 8.0ms preprocess, 291.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 110.58184814453125
# Frame height: 480
# Distance is  5165.404716816069
# Latency: 0.0000 seconds
# Memory Usage: 623.70 MB
#
# 0: 480x640 1 cat, 1 vase, 323.7ms
# Speed: 6.0ms preprocess, 323.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 301.6ms
# Speed: 12.0ms preprocess, 301.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 108.1636962890625
# Frame height: 480
# Distance is  5280.884618379667
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 290.3ms
# Speed: 11.0ms preprocess, 290.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.67 MB
#
# 0: 480x640 1 cat, 1 vase, 297.8ms
# Speed: 7.5ms preprocess, 297.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 106.0010986328125
# Frame height: 480
# Distance is  5388.623395108717
# Latency: 0.0000 seconds
# Memory Usage: 623.69 MB
#
# 0: 480x640 1 cat, 292.8ms
# Speed: 9.0ms preprocess, 292.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.69 MB
#
# 0: 480x640 1 cat, 1 vase, 302.7ms
# Speed: 6.0ms preprocess, 302.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 417.7447204589844
# Frame height: 480
# Distance is  1367.342235641928
# Latency: 0.0000 seconds
# Memory Usage: 623.69 MB
#
# 0: 480x640 1 cat, 1 vase, 254.6ms
# Speed: 10.0ms preprocess, 254.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.68 MB
#
# 0: 480x640 1 cat, 234.8ms
# Speed: 5.0ms preprocess, 234.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 422.899169921875
# Frame height: 480
# Distance is  1350.6765693238924
# Latency: 0.0000 seconds
# Memory Usage: 623.69 MB
#
# 0: 480x640 1 cat, 224.8ms
# Speed: 4.5ms preprocess, 224.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.70 MB
#
# 0: 480x640 1 cat, 242.8ms
# Speed: 5.0ms preprocess, 242.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 426.16229248046875
# Frame height: 480
# Distance is  1340.3344455356253
# Latency: 0.0000 seconds
# Memory Usage: 623.70 MB
#
# 0: 480x640 1 person, 1 cat, 200.3ms
# Speed: 5.0ms preprocess, 200.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.70 MB
#
# 0: 480x640 1 person, 232.3ms
# Speed: 5.0ms preprocess, 232.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 623.70 MB
#
# 0: 480x640 1 person, 213.0ms
# Speed: 5.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 422.17547607421875
# Frame height: 480
# Distance is  1352.9919011676145
# Latency: 0.0000 seconds
# Memory Usage: 623.73 MB
#
# 0: 480x640 1 person, 136.2ms
# Speed: 6.0ms preprocess, 136.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 274.47474670410156
# Frame height: 480
# Distance is  2081.0657696526964
# Latency: 0.0000 seconds
# Memory Usage: 624.09 MB
#
# 0: 480x640 1 person, 138.1ms
# Speed: 6.2ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 399.72581481933594
# Frame height: 480
# Distance is  1428.9795125145101
# Latency: 0.0000 seconds
# Memory Usage: 620.82 MB
#
# 0: 480x640 1 person, 130.6ms
# Speed: 4.1ms preprocess, 130.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 396.68946838378906
# Frame height: 480
# Distance is  1439.9172287764784
# Latency: 0.0000 seconds
# Memory Usage: 620.87 MB
#
# 0: 480x640 1 person, 130.6ms
# Speed: 6.6ms preprocess, 130.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 396.3133544921875
# Frame height: 480
# Distance is  1441.2837557086664
# Latency: 0.0000 seconds
# Memory Usage: 620.90 MB
#
# 0: 480x640 1 person, 135.2ms
# Speed: 10.6ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 393.9803466796875
# Frame height: 480
# Distance is  1449.8185120497776
# Latency: 0.0000 seconds
# Memory Usage: 620.86 MB
#
# 0: 480x640 1 person, 1 cat, 127.4ms
# Speed: 11.9ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 453.477783203125
# Frame height: 480
# Distance is  1259.5986422209003
# Latency: 0.0000 seconds
# Memory Usage: 620.85 MB
#
# 0: 480x640 1 cat, 122.2ms
# Speed: 2.0ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 620.85 MB
#
# 0: 480x640 1 person, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 620.85 MB
#
# 0: 480x640 1 person, 134.3ms
# Speed: 5.0ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 620.92 MB
#
# 0: 480x640 1 cat, 127.1ms
# Speed: 2.0ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 438.7184753417969
# Frame height: 480
# Distance is  1301.9738901011392
# Latency: 0.0000 seconds
# Memory Usage: 624.20 MB
#
# 0: 480x640 1 cat, 132.0ms
# Speed: 3.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.20 MB
#
# 0: 480x640 1 person, 1 cat, 126.7ms
# Speed: 3.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 213.1ms
# Speed: 3.0ms preprocess, 213.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 450.0609130859375
# Frame height: 480
# Distance is  1269.1615365650102
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 cat, 219.1ms
# Speed: 5.0ms preprocess, 219.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 cat, 220.7ms
# Speed: 4.0ms preprocess, 220.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 cat, 1 mouse, 249.0ms
# Speed: 5.0ms preprocess, 249.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 151.352294921875
# Frame height: 480
# Distance is  3773.9764718786846
# Latency: 0.0000 seconds
# Memory Usage: 624.24 MB
#
# 0: 480x640 1 person, 1 mouse, 228.5ms
# Speed: 5.0ms preprocess, 228.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.24 MB
#
# 0: 480x640 1 person, 206.9ms
# Speed: 5.2ms preprocess, 206.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 1 mouse, 199.9ms
# Speed: 4.0ms preprocess, 199.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 148.6365966796875
# Frame height: 480
# Distance is  3842.9297545808217
# Latency: 0.0000 seconds
# Memory Usage: 624.25 MB
#
# 0: 480x640 1 person, 219.5ms
# Speed: 5.0ms preprocess, 219.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 197.2ms
# Speed: 5.0ms preprocess, 197.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 423.67259216308594
# Frame height: 480
# Distance is  1348.2108839840312
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 834.7ms
# Speed: 5.0ms preprocess, 834.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 426.48924255371094
# Frame height: 480
# Distance is  1339.3069344019025
# Latency: 0.0000 seconds
# Memory Usage: 624.20 MB
#
# 0: 480x640 2 persons, 273.8ms
# Speed: 6.0ms preprocess, 273.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 205.9ms
# Speed: 4.0ms preprocess, 205.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Bounding box height: 416.2279052734375
# Frame height: 480
# Distance is  1372.325095850445
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 213.4ms
# Speed: 4.0ms preprocess, 213.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 206.4ms
# Speed: 6.0ms preprocess, 206.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Latency: 0.0000 seconds
# Memory Usage: 624.21 MB
#
# 0: 480x640 1 person, 220.5ms
# Speed: 6.0ms preprocess, 220.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 395.3980712890625
# Frame height: 480
# Distance is  1444.620096749067
# Latency: 0.0000 seconds
# Memory Usage: 624.22 MB
#
# 0: 480x640 1 person, 248.4ms
# Speed: 4.3ms preprocess, 248.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 378.1473388671875
# Frame height: 480
# Distance is  1510.5223316158686
# Latency: 0.0000 seconds
# Memory Usage: 620.94 MB
#
# 0: 480x640 1 person, 142.1ms
# Speed: 6.4ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 376.1844482421875
# Frame height: 480
# Distance is  1518.4040772261312
# Latency: 0.0000 seconds
# Memory Usage: 620.90 MB
#
# 0: 480x640 1 person, 132.7ms
# Speed: 3.1ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 375.81158447265625
# Frame height: 480
# Distance is  1519.9105711483464
# Latency: 0.0000 seconds
# Memory Usage: 620.90 MB
#
# 0: 480x640 1 person, 134.5ms
# Speed: 7.3ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 374.87339782714844
# Frame height: 480
# Distance is  1523.7144148152556
# Latency: 0.0000 seconds
# Memory Usage: 620.93 MB
#
# 0: 480x640 1 person, 207.1ms
# Speed: 4.4ms preprocess, 207.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 375.42913818359375
# Frame height: 480
# Distance is  1521.458890387644
# Latency: 0.0000 seconds
# Memory Usage: 620.95 MB
#
# 0: 480x640 1 person, 135.1ms
# Speed: 5.7ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 382.1658935546875
# Frame height: 480
# Distance is  1494.6388718444389
# Latency: 0.0000 seconds
# Memory Usage: 620.96 MB
#
# 0: 480x640 1 person, 136.9ms
# Speed: 6.3ms preprocess, 136.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 377.4544677734375
# Frame height: 480
# Distance is  1513.2951091278535
# Latency: 0.0000 seconds
# Memory Usage: 620.96 MB
#
# 0: 480x640 1 person, 128.9ms
# Speed: 6.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 373.4638671875
# Frame height: 480
# Distance is  1529.4652312728965
# Latency: 0.0000 seconds
# Memory Usage: 622.66 MB
#
# 0: 480x640 1 person, 128.5ms
# Speed: 5.2ms preprocess, 128.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 385.95013427734375
# Frame height: 480
# Distance is  1479.9839390379268
# Latency: 0.0000 seconds
# Memory Usage: 623.79 MB
#
# 0: 480x640 1 person, 117.4ms
# Speed: 3.1ms preprocess, 117.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 382.59625244140625
# Frame height: 480
# Distance is  1492.9576449196347
# Latency: 0.0000 seconds
# Memory Usage: 623.80 MB
#
# 0: 480x640 1 person, 134.8ms
# Speed: 7.5ms preprocess, 134.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 384.98016357421875
# Frame height: 480
# Distance is  1483.712809244211
# Latency: 0.0000 seconds
# Memory Usage: 623.82 MB
#
# 0: 480x640 1 person, 227.1ms
# Speed: 4.0ms preprocess, 227.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 386.35841369628906
# Frame height: 480
# Distance is  1478.419984530251
# Latency: 0.0000 seconds
# Memory Usage: 623.92 MB
#
# 0: 480x640 1 person, 139.0ms
# Speed: 6.9ms preprocess, 139.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
# Bounding box height: 382.69166564941406
# Frame height: 480
# Distance is  1492.5854186834565
# Latency: 0.0000 seconds
# Memory Usage: 623.93 MB
#
# 0: 480x640 1 person, 138.8ms
# Speed: 3.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Alert! Person very close
